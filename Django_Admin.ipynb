# %% [markdown]
# # Proyecto Django
# Creación masiva de productos y uso de fixtures.

# %%
from ecommerce.models import ProductModel
ProductModel.objects.count()

# %% [markdown]
# ## Resultado esperado
# Debe mostrar 500 productos en la base de datos.
